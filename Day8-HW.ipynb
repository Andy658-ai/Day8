# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 8
# ---------------------------------------
#
# GOALS:
#
# 1. Load data into Python that you find online
# 2. Understand data types and fix some errors
# 3. Find your own data to play with
#
# ----------------------------------------------------------
#
# This homework has **5 questions** and **1 problem**.
#
# NOTE: Be kind to yourself. Working with data can be hard! Every data set is different. **Seriously** come get help! Come to lab!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Try reading in some data - csv
#
# Go to the [Cal Fire Website](https://www.fire.ca.gov/incidents) and scroll to the bottom to see the Incident Data. We will download the file named **ALL DATA AS CSV** this should put the data file into your Downloads folder.
#
# Next you need to move the file **mapdataall.csv** from your Downloads folder into your Day8 folder where you are doing your homework. You can open your Downloads folder and drag the file into JupyterLab side bar. Then I can run the command
#
#     DF_raw = pd.read_csv('mapdataall.csv')
#
# to load the data and look at the data frame.

# %%
# Your code here
DF_raw = pd.read_csv('mapdataall.csv')
DF_raw
# Out:
#       incident_name incident_is_final  incident_date_last_update  \
# 0       Bridge Fire                 Y       2018-01-09T13:46:00Z
# 1         Pala Fire                 Y       2020-09-16T14:07:35Z
# 2        River Fire                 Y       2022-10-24T11:39:23Z
# 3     Fawnskin Fire                 Y       2013-04-22T09:00:00Z
# 4         Gold Fire                 Y       2013-05-01T07:00:00Z
# ...             ...               ...                        ...
# 2739  Two Mile Fire                 Y       2024-10-06T10:11:56Z
# 2740   Tuledad Fire                 N  2024-10-07T07:20:30-07:00
# 2741   Hambone Fire                 N       2024-10-07T08:46:35Z
# 2742  Verjeles Fire                 N       2024-10-07T08:57:16Z
# 2743      Wood Fire                 N       2024-10-07T08:57:24Z
#
#      incident_date_created          incident_administrative_unit  \
# 0     2017-10-31T11:22:00Z       Shasta-Trinity National Forest
# 1     2009-05-24T14:56:00Z               CAL FIRE San Diego Unit
# 2     2013-02-24T08:16:00Z          CAL FIRE San Bernardino Unit
# 3     2013-04-20T17:30:00Z        San Bernardino National Forest
# 4     2013-04-30T12:59:00Z  CAL FIRE Madera-Mariposa-Merced Unit
# ...                    ...                                   ...
# 2739  2024-10-03T16:01:18Z        CAL FIRE Sonoma-Lake-Napa Unit
# 2740  2024-10-06T12:36:35Z             Bureau of Land Management
# 2741  2024-10-06T13:39:46Z                CAL FIRE Siskiyou Unit
# 2742  2024-10-06T16:45:33Z      CAL FIRE Nevada-Yuba-Placer Unit
# 2743  2024-10-06T19:57:47Z      CAL FIRE Humboldt-Del Norte Unit
#
#       incident_administrative_unit_url incident_county  \
# 0                                  NaN          Shasta
# 1                                  NaN       San Diego
# 2                                  NaN            Inyo
# 3                                  NaN  San Bernardino
# 4                                  NaN          Madera
# ...                                ...             ...
# 2739                               NaN          Colusa
# 2740                               NaN          Lassen
# 2741                               NaN        Siskiyou
# 2742                               NaN            Yuba
# 2743                               NaN        Humboldt
#
#                                       incident_location  \
# 0     I-5 and Turntable Bay, 7 miles NE of Shasta Lake
# 1           Hwy 76 and Pala Temecula, northwest of Pala
# 2     south of Narrow Gauge Rd & north of Hwy 136, e...
# 3     west of Delamar Mountain, north of the communi...
# 4     Between Road 210 and Road 200 near Fine Gold C...
# ...                                                 ...
# 2739      Lurline Ave. and Two Mile Road, Colusa County
# 2740  Marr Road and Tuledad Road, northeast of Susan...
# 2741  Forest Road 24 and Forest Road 40N57 in the Po...
# 2742               Los Verjeles Road and Loma Rica Road
# 2743  Wood Ranch Road and Redwood Drive, southwest o...
#
#       incident_acres_burned  incident_containment  ... incident_latitude  \
# 0                      37.0                 100.0  ...         40.774000
# 1                     122.0                 100.0  ...          1.000000
# 2                     407.0                 100.0  ...         36.602575
# 3                      30.0                 100.0  ...         34.288877
# 4                     274.0                 100.0  ...         37.116295
# ...                     ...                   ...  ...               ...
# 2739                   10.0                 100.0  ...         39.218344
# 2740                  450.0                  50.0  ...         40.887485
# 2741                   15.0                  25.0  ...         41.281183
# 2742                   12.0                 100.0  ...         39.357400
# 2743                   25.0                  25.0  ...         40.176118
#
#      incident_type                           incident_id  \
# 0              NaN  2ca11d45-8139-4c16-8af0-880d99b21e82
# 1         Wildfire  8f61f461-552d-4538-b186-35ab030da416
# 2              NaN  094719ba-a47b-4abb-9ec5-a506b2b9fd23
# 3              NaN  58f89ff8-bd3e-4355-b1c0-8fa05c747d3f
# 4              NaN  357ffc13-bef9-48eb-810f-c5de851972eb
# ...            ...                                   ...
# 2739      Wildfire  6fb9c69a-49be-4edc-8a5f-96d49df32cb1
# 2740      Wildfire  ccc0846d-97a2-4031-bf61-b02df50ca6b3
# 2741      Wildfire  93d607c9-fc8d-4e3c-b19b-3feb61bb224e
# 2742      Wildfire  1b69ebdd-1add-4f85-a9f9-47275bc5118e
# 2743      Wildfire  100b8102-e9f6-411f-9440-26b92b8ebe94
#
#                                            incident_url  \
# 0     https://www.fire.ca.gov/incidents/2017/10/31/b...
# 1     https://www.fire.ca.gov/incidents/2009/5/24/pa...
# 2     https://www.fire.ca.gov/incidents/2013/2/24/ri...
# 3     https://www.fire.ca.gov/incidents/2013/4/20/fa...
# 4     https://www.fire.ca.gov/incidents/2013/4/30/go...
# ...                                                 ...
# 2739  https://www.fire.ca.gov/incidents/2024/10/3/tw...
# 2740  https://www.fire.ca.gov/incidents/2024/10/6/tu...
# 2741  https://www.fire.ca.gov/incidents/2024/10/6/ha...
# 2742  https://www.fire.ca.gov/incidents/2024/10/6/ve...
# 2743  https://www.fire.ca.gov/incidents/2024/10/6/wo...
#
#      incident_date_extinguished incident_dateonly_extinguished  \
# 0          2018-01-09T13:46:00Z                     2018-01-09
# 1          2009-05-25T00:00:00Z                     2009-05-25
# 2          2013-02-28T20:00:00Z                     2013-02-28
# 3          2013-04-22T09:00:00Z                     2013-04-22
# 4          2013-05-01T07:00:00Z                     2013-05-01
# ...                         ...                            ...
# 2739       2024-10-04T22:00:00Z                     2024-10-04
# 2740                        NaN                            NaN
# 2741                        NaN                            NaN
# 2742       2024-10-07T08:04:00Z                     2024-10-07
# 2743                        NaN                            NaN
#
#      incident_dateonly_created is_active calfire_incident notification_desired
# 0                   2017-10-31         N            False                False
# 1                   2009-05-24         N             True                False
# 2                   2013-02-24         N             True                False
# 3                   2013-04-20         N            False                False
# 4                   2013-04-30         N             True                False
# ...                        ...       ...              ...                  ...
# 2739                2024-10-03         N             True                False
# 2740                2024-10-06         Y            False                False
# 2741                2024-10-06         Y             True                False
# 2742                2024-10-06         Y             True                False
# 2743                2024-10-06         Y             True                False
#
# [2744 rows x 23 columns]

# %% [markdown]
# **Q1** How many variables and observations?
#
# **Q2** How many different incident types are there?
#
# **Q3** Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident. You will probably need to make a mask to remove very small and very large fires. How many fires burned more than 100,000 acres? What is the largest fire in the data?
#
# **Extra Q** EXTRA - CHALLENGE - See if you can create a graph that answers the question: Are fires getting bigger or more frequent over time? You get complete creative control on how to answer this question!

# %%
# Q1 How many variables and observations?
DF_raw.shape
# Out:
# (2744, 23)

# %% [markdown]
# This data has 2744 observations and 23 variables

# %%
DF_raw.columns
# Out:
# Index(['incident_name', 'incident_is_final', 'incident_date_last_update',
#        'incident_date_created', 'incident_administrative_unit',
#        'incident_administrative_unit_url', 'incident_county',
#        'incident_location', 'incident_acres_burned', 'incident_containment',
#        'incident_control', 'incident_cooperating_agencies',
#        'incident_longitude', 'incident_latitude', 'incident_type',
#        'incident_id', 'incident_url', 'incident_date_extinguished',
#        'incident_dateonly_extinguished', 'incident_dateonly_created',
#        'is_active', 'calfire_incident', 'notification_desired'],
#       dtype='object')

# %%
#Q2 How many different incident types are there?
columns=['incident_name' ,'incident_type']
DF_raw[columns].groupby('incident_type').sum()
# Out:
#                                                    incident_name
# incident_type
# Fire           Refuge FireLine FireWestwood FireLuis FireCoyo...
# Flood                                             Honey Flooding
# Wildfire       Pala FireSand FireWragg FireButte FireAtlas Fi...

# %%
#Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident.
#You will probably need to make a mask to remove very small and very large fires.How many fires burned more than 100,000 acres? 
#What is the largest fire in the data?

fig = px.histogram(
                  DF_raw,
                  x='incident_acres_burned',
                  y='calfire_incident',
                  color_discrete_sequence=['gray'],
                  nbins= 6)
fig.update_layout(bargap=0.1,
                  title='Histogram of acres burned.')
mask = (DF_raw['calfire_incident'])
fig.show()

# %% [markdown]
# The larges fire in the data is the non calfire_incident

# %%
#Extra Q EXTRA - CHALLENGE - See if you can create a graph that answers the question:
#Are fires getting bigger or more frequent over time? You get complete creative control on how to answer this question!
fig = px.histogram(DF_raw,
                   x='incident_date_last_update',
                   labels={'incident_acres_burned':'incident_acres_burned'},
                   opacity=0.3,
                   color_discrete_sequence=['red'])
fig.update_layout(bargap=0.3, title=
            'Are fires getting bigger or more frequent over time?',
            title_x=0.5)
fig.show()

# %%
#your code here
DF[0]
# Out:
#                                                    Film  Year  Awards  \
# 0                                           Oppenheimer  2023     7.0
# 1                                           Poor Things  2023     4.0
# 2                                  The Zone of Interest  2023     2.0
# 3                                      American Fiction  2023     1.0
# 4                                     Anatomy of a Fall  2023     1.0
# ...                                                 ...   ...     ...
# 1368                            The Yankee Doodle Mouse  1943     1.0
# 1369                                       The Yearling  1946     2.0
# 1370  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964     1.0
# 1371                         You Can't Take It with You  1938     2.0
# 1372                    Zorba the Greek (Alexis Zorbas)  1964     3.0
#
#       Nominations
# 0              13
# 1              11
# 2               5
# 3               5
# 4               5
# ...           ...
# 1368            1
# 1369            7
# 1370            1
# 1371            7
# 1372            7
#
# [1373 rows x 4 columns]

# %%
# Here is some helper code
# This is code that will read in the data and then fix the Year column
my_website = "https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"
DF = pd.read_html(my_website)
DF_raw = DF[0]
DF_raw['Year'] = DF_raw['Year'].apply(lambda x: int(x.split('/')[0]))
DF_raw['Year'].value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
# Out:
#     Year  count
# 0   1945     21
# 1   1949     20
# 2   1942     20
# 3   1950     19
# 4   1948     19
# ..   ...    ...
# 91  1931     10
# 92  1932      9
# 93  1928      7
# 94  1929      6
# 95  1930      6
#
# [96 rows x 2 columns]

# %%
DF_raw.describe()
# Out:
#               Year
# count  1373.000000
# mean   1975.864530
# std      27.416755
# min    1927.000000
# 25%    1952.000000
# 50%    1975.000000
# 75%    2000.000000
# max    2023.000000

# %%
DF_raw.columns
# Out:
# Index(['Film', 'Year', 'Awards', 'Nominations'], dtype='object')

# %%
my_columns = ['Year', 'Awards', 'Nominations']
DF_raw[my_columns].describe()
# Out:
#               Year
# count  1373.000000
# mean   1975.864530
# std      27.416755
# min    1927.000000
# 25%    1952.000000
# 50%    1975.000000
# 75%    2000.000000
# max    2023.000000

# %%
year_data = DF_raw['Year'].value_counts()
DF_year = year_data.reset_index().rename(columns={"index": "value", 0: "count"})
DF_year
# Out:
#     Year  count
# 0   1945     21
# 1   1949     20
# 2   1942     20
# 3   1950     19
# 4   1948     19
# ..   ...    ...
# 91  1931     10
# 92  1932      9
# 93  1928      7
# 94  1929      6
# 95  1930      6
#
# [96 rows x 2 columns]

# %% [markdown]
# **Q4** Following along with the lecture notes or video, fix the data in the 'Awards' column.

# %%
# Your code here


my_columns = ['Year', 'Awards', 'Nominations']
DF_raw[my_columns].describe()
# Out:
#               Year
# count  1373.000000
# mean   1975.864530
# std      27.416755
# min    1927.000000
# 25%    1952.000000
# 50%    1975.000000
# 75%    2000.000000
# max    2023.000000

# %%
DF_raw.dtypes
# Out:
# Film           object
# Year            int64
# Awards         object
# Nominations    object
# dtype: object

# %% [markdown]
# This code is only getting data from the columns 'Year', 'Awards', and 'Nominations'
# then (.describe()) is getting the data to be more descriptive and provides a summary

# %%
year_data = DF_raw['Awards'].value_counts()
DF_year = year_data.reset_index().rename(columns={"index": "value", 0: "count"})
DF_year
# Out:
#       Awards  count
# 0          1    979
# 1          2    156
# 2          3     77
# 3          4     47
# 4      0 (1)     32
# 5          5     25
# 6          7     12
# 7          6     12
# 8      1 (1)      8
# 9          8      7
# 10        11      3
# 11         9      3
# 12     0 (2)      3
# 13  0 (1)[1]      1
# 14     3 (1)      1
# 15     4 (1)      1
# 16     6 (1)      1
# 17     5 (1)      1
# 18     7 (1)      1
# 19     8 (2)      1
# 20     2 (1)      1
# 21        10      1

# %% [markdown]
# The graph is focusing only in the column 'Award' and ins counting all of them, but it is showing an error

# %% [markdown]
# **Q5** Now try to fix the data in the "Nominations" column - see if you can do it without looking at the answer.

# %%
# Your code here
nom_data = DF_raw['Nominations'].value_counts()
DF_nom = nom_data.reset_index().rename(columns={"index": "value", 0: "count"})
show(DF_nom)
print('I can see that I want the data to the left of the [ character')

DF_raw['Nominations'] = DF_raw['Nominations'].apply(lambda x: int(x.split('[')[0]))
award_data = DF_raw['Awards'].value_counts()
DF_award = award_data.reset_index().rename(columns={"index": "value", 0: "count"})
show(DF_award)

DF_raw.dtypes
# Out:
# <table id="itables_c780895d_3249_421f_85ff_c7006374ed4a" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Nominations</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c780895d_3249_421f_85ff_c7006374ed4a:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1", 550], ["2", 141], ["4", 113], ["5", 104], ["3", 103], ["6", 78], ["7", 75], ["8", 61], ["10", 39], ["9", 31], ["11", 24], ["12", 17], ["0", 14], ["13", 11], ["14", 3], ["1[2]", 1], ["3[3]", 1], ["10[4]", 1], ["1[5]", 1], ["1[6]", 1], ["4[7]", 1], ["6[8]", 1], ["4[9]", 1], ["6[10]", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# I can see that I want the data to the left of the [ character
# <table id="itables_8f7f0d9e_ba6c_49d6_b359_262f4f41e17e" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Awards</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_8f7f0d9e_ba6c_49d6_b359_262f4f41e17e:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1", 979], ["2", 156], ["3", 77], ["4", 47], ["0 (1)", 32], ["5", 25], ["7", 12], ["6", 12], ["1 (1)", 8], ["8", 7], ["11", 3], ["9", 3], ["0 (2)", 3], ["0 (1)[1]", 1], ["3 (1)", 1], ["4 (1)", 1], ["6 (1)", 1], ["5 (1)", 1], ["7 (1)", 1], ["8 (2)", 1], ["2 (1)", 1], ["10", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# Film           object
# Year            int64
# Awards         object
# Nominations     int64
# dtype: object

# %% [markdown]
# ## Problem 1
#
# Your homework today will be to see if you can find some data of your own. This can be the first steps you take toward your final project.
#
# You should:
#
# * Find some data online
# * Read that data into Python using the Pandas commands we learned
# * Look at the DataFrame - number of variables, number of observations, AND the dtypes. Comment on what you see.
# * Try to do summary statistics (.describe()). Does it work like expected?
# * Attempt to fix any data, or explain why the data does not need to be fixed.
# * Make some sort of graph using columns in your data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
DF_raw = pd.read_csv('BKB_WaterQualityData_2020084.csv')
DF_raw
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                     7.3              0.40             0.40              5.9
# 1                     7.4              0.20             0.35              3.0
# 2                     7.2              0.25             0.60              5.9
# 3                     7.4              0.35             0.50             10.0
# 4                     7.2              0.20             0.40              1.6
# ...                   ...               ...              ...              ...
# 2366                  7.0              4.00             1.20             25.0
# 2367                  7.0              0.30             0.60             18.0
# 2368                  7.0              0.40             0.90             13.0
# 2369                  7.0              0.45             0.90             20.0
# 2370                  7.0              0.10             0.10             10.0
#
#       Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# 0                  8.0          46.40        11:00        NaN          NaN
# 1                  2.6          36.68        11:30        NaN          NaN
# 2                  7.6          45.68         9:45        NaN          NaN
# 3                  2.7          36.86          NaN        NaN          NaN
# 4                  0.0          32.00        10:30        NaN          NaN
# ...                ...            ...          ...        ...          ...
# 2366               NaN          78.00        09:30    Sue Poe   11/13/2019
# 2367               NaN          58.00        09:30    Sue Poe   11/13/2019
# 2368               NaN          49.00        09:20    Sue Poe   11/13/2019
# 2369               NaN          65.00        09:45    Sue Poe   11/13/2019
# 2370               NaN          42.00        09:40    Sue Poe   11/13/2019
#
#           WhoVerified  AirTemp (C)  Year
# 0                 NaN     8.000000  1994
# 1                 NaN     2.600000  1994
# 2                 NaN     7.600000  1994
# 3                 NaN     2.700000  1994
# 4                 NaN     0.000000  1994
# ...               ...          ...   ...
# 2366  Christine Folks    25.555556  2018
# 2367  Christine Folks    14.444444  2018
# 2368  Christine Folks     9.444444  2018
# 2369  Christine Folks    18.333333  2018
# 2370  Christine Folks     5.555556  2018
#
# [2371 rows x 17 columns]

# %%
DF_raw.shape
# Out:
# (2371, 17)

# %% [markdown]
# with this code it shows that are 2371 rows and 17 column in th graph.

# %%
DF_raw.dtypes
# Out:
# Site_Id                     object
# Unit_Id                     object
# Read_Date                   object
# Salinity (ppt)             float64
# Dissolved Oxygen (mg/L)    float64
# pH (standard units)        float64
# Secchi Depth (m)           float64
# Water Depth (m)            float64
# Water Temp (?C)            float64
# Air Temp-Celsius           float64
# Air Temp (?F)              float64
# Time (24:00)                object
# Field_Tech                  object
# DateVerified                object
# WhoVerified                 object
# AirTemp (C)                float64
# Year                         int64
# dtype: object

# %% [markdown]
# i see that i  have 9 float64, 1 int64, and 7 object dtypes and at the bottom it says that the dtype is object

# %%
DF_raw.columns
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
 DF_raw.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     2241.000000              1520.000000          2276.000000
# mean         0.717068                 6.646263             7.168212
# std          1.230819                 2.506608             0.788485
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.800000             6.500000
# 50%          0.000000                 6.500000             7.000000
# 75%          1.000000                 8.500000             7.500000
# max          9.000000                15.100000             9.900000
# %%
fig = px.histogram(DF_raw,
                     nbins=2,
                     x = 'Read_Date',
                     color_discrete_sequence=['yellow'])
fig.update_layout(bargap=0.1,
                  title='Air Temp-Celsius',
                  title_x = 0.5)
fig.show()

# %%
my_columns = [ 'Dissolved Oxygen (mg/L)','Time (24:00)',  'Air Temp (?F)']
DF_lead_time_sorted = DF_raw[my_columns].sort_values(  'Air Temp (?F)', ascending=False)
show(DF_lead_time_sorted)
# Out:
# <table id="itables_ae0e187b_5031_4d3b_92b2_9c59059196fd" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dissolved Oxygen (mg/L)</th>
#       <th>Time (24:00)</th>
#       <th>Air Temp (?F)</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ae0e187b_5031_4d3b_92b2_9c59059196fd:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[244, 7.2, "7:12", 92.3], [346, 1.6, "9:36", 91.4], [43, 1.6, "12:00", 90.5], [967, NaN, "0:00", 89.0], [1656, 5.8, "0:00", 89.0], [203, 7.4, "16:48", 88.7], [1009, 4.3, "0:00", 88.0], [1865, 6.4, "0:00", 88.0], [513, 4.5, "0:00", 88.0], [988, 4.8, "0:00", 88.0], [947, NaN, "0:00", 88.0], [421, NaN, "19:12", 87.8], [159, 7.3, "19:12", 87.8], [353, 2.2, "19:12", 87.8], [383, 3.0, "19:12", 87.8], [370, 2.8, "NaN", 87.8], [1032, 5.4, "9:36", 87.4], [342, 10.8, "2:24", 87.1], [1687, NaN, "0:00", 87.0], [2290, NaN, "11:05", 87.0], [2288, NaN, "10:58", 87.0], [669, NaN, "0:00", 87.0], [649, NaN, "0:00", 87.0], [1636, 3.2, "0:00", 87.0], [1634, 5.7, "0:00", 87.0], [2277, NaN, "10:45", 87.0], [1551, 3.4, "0:00", 87.0], [1313, NaN, "0:00", 87.0], [1594, NaN, "0:00", 87.0], [1336, 5.1, "0:00", 87.0], [627, NaN, "0:00", 87.0], [1573, NaN, "0:00", 87.0], [160, 7.6, "21:36", 86.9], [19, 9.8, "10:15", 86.9], [319, 9.7, "17:16", 86.72], [382, 7.0, "12:57", 86.54], [1529, 4.2, "0:00", 86.0], [1689, NaN, "0:00", 86.0], [206, 8.0, "0:00", 86.0], [276, 9.0, "NaN", 86.0], [1289, NaN, "0:00", 86.0], [2299, 5.9, "10:30", 86.0], [202, 7.1, "0:00", 86.0], [1616, 3.1, "0:00", 86.0], [950, NaN, "0:00", 86.0], [970, NaN, "0:00", 86.0], [991, 5.2, "0:00", 86.0], [369, 2.5, "11:02", 85.46], [205, 7.5, "2:24", 85.1], [341, 11.0, "2:24", 85.1], [114, 7.8, "2:24", 85.1], [1036, 3.7, "0:00", 85.0], [2238, NaN, "10:45", 85.0], [1864, NaN, "0:00", 85.0], [1686, 4.8, "0:00", 85.0], [1290, 3.8, "0:00", 85.0], [1802, 3.7, "0:00", 85.0], [1592, NaN, "0:00", 85.0], [1314, 2.8, "0:00", 85.0], [1633, NaN, "0:00", 85.0], [2310, 6.5, "09:35", 85.0], [691, NaN, "0:00", 85.0], [1571, NaN, "0:00", 85.0],